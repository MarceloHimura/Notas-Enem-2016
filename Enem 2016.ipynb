# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline
from sklearn.preprocessing  import OneHotEncoder

# %%
df  = pd.read_csv('train.csv')

# %%
df[df.drop(dropavel,axis=1).isnull().any(1)].drop(dropavel,axis=1)
# Out:
#        Unnamed: 0                              NU_INSCRICAO  NU_ANO  \
# 0               1  ed50e8aaa58e7a806c337585efee9ca41f1eb1ad    2016
# 1               2  2c3acac4b33ec2b195d77e7c04a2d75727fad723    2016
# 2               3  f4545f8ccb9ff5c8aad7d32951b3f251a26e6568    2016
# 3               4  3d6ec248fef899c414e77f82d5c6d2bffbeaf7fe    2016
# 4               5  bf896ac8d3ecadd6dba1dfbf50110afcbf5d3268    2016
# ...           ...                                       ...     ...
# 13725        4582  aadf671ef8c1c6efa42e69432093ab83c17a52ac    2016
# 13726        4583  461f7ef2753d9d5fa0b054930d6b0e0eec318e81    2016
# 13727        4584  5354503700ecf2388f68990435390b6e1ad454ee    2016
# 13728        4585  c7a9e94a42bd76b7978f13c013a61702e36cc42c    2016
# 13729        4586  0af8939c470a600b30bdaa80375ee0db848b0e35    2016
#
#        CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# 0                      4314902            Porto Alegre                43
# ...

# %%
df['NU_NOTA_MT'].fillna(df['NU_NOTA_MT'].mean(),inplace=True)
model_1 = df.drop(['NU_INSCRICAO','NU_ANO','NU_NOTA_MT'],axis=1)
model_1.drop(dropavel,inplace=True,axis=1)
model_1 = pd.get_dummies(model_1)

# %%
df['NU_NOTA_MT'].shape
# Out:
# (13730,)

# %%
df.describe()
# Out:
#          Unnamed: 0   NU_ANO  CO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# count  13730.000000  13730.0             1.373000e+04      13730.000000
# mean    2288.173926   2016.0             3.088548e+06         30.736708
# std     1321.230607      0.0             9.890495e+05          9.862405
# min        0.000000   2016.0             1.100023e+06         11.000000
# 25%     1144.000000   2016.0             2.307650e+06         23.000000
# 50%     2288.000000   2016.0             3.118601e+06         31.000000
# 75%     3432.000000   2016.0             3.550308e+06         35.000000
# max     4586.000000   2016.0             5.300108e+06         53.000000
#
#            NU_IDADE  TP_ESTADO_CIVIL   TP_COR_RACA  TP_NACIONALIDADE  \
# count  13730.000000     13202.000000  13730.000000      13730.000000
# mean      21.593809         0.116043      2.185652          1.048871
# std        7.043654         0.365986      1.007285          0.258895
# ...

# %% [markdown]
# nu_inscrição ; ano ;'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009',
#        'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018',
#        'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025', 'Q026', 'Q027',
#        'Q028', 'Q029', 'Q030', 'Q031', 'Q032', 'Q033', 'Q034', 'Q035', 'Q036',
#        'Q037', 'Q038', 'Q039', 'Q040', 'Q041', 'Q042', 'Q043', 'Q044', 'Q045',
#        'Q046', 'Q047', 'Q048', 'Q049', 'Q050'
#
#        Perguntas sobre a vida da pessoa pode n ser relevantes
#
#        tranformarn NaN em algo categorico e dps passar pro dummies ????

# %%
model_1.isnull().sum().sum()
# Out:
# 0

# %%
df['NU_NOTA_MT'].head()
# Out:
# 0    399.4
# 1    459.8
# 2      0.0
# 3      0.0
# 4      0.0
# Name: NU_NOTA_MT, dtype: float64

# %%
model_1.dropna(inplace=True,axis=1)
#target.dropna(inplace=True)

target.shape , model_1.shape
# Out:
# ((13730,), (13730, 8215))

# %%
df.columns[-90:]
# Out:
# Index(['IN_SALA_ACOMPANHANTE', 'IN_MOBILIARIO_ESPECIFICO',
#        'IN_MATERIAL_ESPECIFICO', 'IN_NOME_SOCIAL', 'IN_CERTIFICADO',
#        'NO_ENTIDADE_CERTIFICACAO', 'CO_UF_ENTIDADE_CERTIFICACAO',
#        'SG_UF_ENTIDADE_CERTIFICACAO', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA', 'TP_PRESENCA_CN',
#        'TP_PRESENCA_CH', 'TP_PRESENCA_LC', 'TP_PRESENCA_MT', 'CO_PROVA_CN',
#        'CO_PROVA_CH', 'CO_PROVA_LC', 'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH',
#        'NU_NOTA_LC', 'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA', 'TX_GABARITO_CN',
#        'TX_GABARITO_CH', 'TX_GABARITO_LC', 'TX_GABARITO_MT',
#        'TP_STATUS_REDACAO', 'NU_NOTA_COMP1', 'NU_NOTA_COMP2', 'NU_NOTA_COMP3',
#        'NU_NOTA_COMP4', 'NU_NOTA_COMP5', 'NU_NOTA_REDACAO', 'Q001', 'Q002',
#        'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011',
# ...

# %%
dropavel = ['CO_PROVA_CN','CO_PROVA_CH', 'CO_PROVA_LC','TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH', 'TX_RESPOSTAS_LC',
       'TX_RESPOSTAS_MT', 'TP_LINGUA', 'TX_GABARITO_CN', 'TX_GABARITO_CH',
       'TX_GABARITO_LC', 'TX_GABARITO_MT', 'TP_STATUS_REDACAO',
       'NU_NOTA_COMP1', 'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4',
       'NU_NOTA_COMP5','Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009',
       'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018',
       'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025', 'Q026', 'Q027',
       'Q028', 'Q029', 'Q030', 'Q031', 'Q032', 'Q033', 'Q034', 'Q035', 'Q036',
       'Q037', 'Q038', 'Q039', 'Q040', 'Q041', 'Q042', 'Q043', 'Q044', 'Q045',
       'Q046', 'Q047', 'Q048', 'Q049', 'Q050']

# %%
model_1.head()
# Out:
#    Unnamed: 0  CO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  NU_IDADE  \
# 0           1                  4314902                43        24
# 1           2                  2304707                23        17
# 2           3                  2304400                23        21
# 3           4                  3304557                33        25
# 4           5                  1302603                13        28
#
#    TP_ESTADO_CIVIL  TP_COR_RACA  TP_NACIONALIDADE  CO_MUNICIPIO_NASCIMENTO  \
# 0              0.0            1                 1                4314902.0
# 1              0.0            3                 1                2304707.0
# 2              0.0            3                 1                2304400.0
# 3              0.0            0                 1                3304557.0
# 4              0.0            2                 1                1505304.0
#
#    CO_UF_NASCIMENTO  TP_ST_CONCLUSAO  ...  SG_UF_PROVA_TO  \
# ...

# %%
target.head()
# Out:
# 0    399.4
# 1    459.8
# 2      NaN
# 3      NaN
# 4      NaN
# Name: NU_NOTA_MT, dtype: float64

# %%
target = df['NU_NOTA_MT'].copy()
#target.replace(np.NaN,"Eunwoo",inplace=True)
target[:5]
# Out:
# 0    399.400000
# 1    459.800000
# 2    482.497928
# 3    482.497928
# 4    482.497928
# Name: NU_NOTA_MT, dtype: float64

# %%
model_1.isnull().sum().sum(), target.isnull().sum().sum()
# Out:
# (0, 0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(model_1, target)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
test = pd.read_csv('test.csv')
#test = pd.get_dummies(test)
#test.replace(np.NaN,, inplace=True)

# %%
test['NU_NOTA_MT'].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896         By definition, these are labels unless 'iloc' is passed in.
# -> 2897         Floats are not allowed as the start, step, or stop of the slice.
#    2898
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NU_NOTA_MT'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-258-295cb0b4ddf9> in <module>
# ...

# %%
test.head()
# Out:
#                                NU_INSCRICAO  CO_UF_RESIDENCIA  \
# 0  73ff9fcc02f0a99919906c942c2e1a1042cdcf98                41
# 1  71a95f9f1b91a82c65ad94abbdf9f54e6066f968                21
# 2  b38a03232f43b11c9d0788abaf060f7366053b6d                23
# 3  70b682d9a3636be23f6120fa9d6b164eb3c6002d                15
# 4  715494628a50142ce8cb17191cfe6d0f3cae0934                41
#
#   SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_COR_RACA  TP_NACIONALIDADE  \
# 0               PR        22       F            3                 1
# 1               MA        26       F            3                 1
# 2               CE        21       M            1                 1
# 3               PA        27       F            3                 1
# 4               PR        18       M            1                 1
#
#    TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  ...  NU_NOTA_COMP5  \
# 0                1                5          1  ...           40.0
# ...

# %%
lr.predict(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-250-5feadb5f9436> in <module>
# ----> 1 lr.predict(test)
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     223             Returns predicted values.
#     224         """
# --> 225         return self._decision_function(X)
#     226
#     227     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     205         check_is_fitted(self)
#     206
# --> 207         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     208         return safe_sparse_dot(X, self.coef_.T,
#     209                                dense_output=True) + self.intercept_
#
# ...

# %%
np.mean((target - lr.predict(test.drop(dropavel,axis=1,inplace=True)))**2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-245-ee0b36ca0261> in <module>
# ----> 1 np.mean((target - lr.predict(test.drop(dropavel,axis=1,inplace=True)))**2)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115         0  1  4
#    4116         1  2  5
# -> 4117         2  3  6
#    4118
#    4119         >>> df.rename({1: 2, 2: 4}, axis='index')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         columns=None,
#    3913         level=None,
# -> 3914         inplace: bool_t = False,
#    3915         errors: str = "raise",
#    3916     ):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...
